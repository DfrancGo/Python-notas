# %% [markdown]
# ## Librerias

# %%
# import math # De esta manera se importa toda la librería math
from math import ceil #De estás maneras lo que se hace es optimizar porque se importa sólo la parte de la librería que vamos a usar
from math import floor
from math import sqrt

numero = 36
raiz_numero = math.sqrt(numero)
print(raiz_numero)

redondeo_arriba = math.ceil(5.3)
print(redondeo_arriba)

redondeo_abajo = math.floor(5.3)
print(redondeo_abajo)
# Out:
# 6.0
# 6
# 5

# %%
import os

print(os.getcwd()) #librería para comunicarse con el ordenador
# Out:
# /home/daniel/Proyectos/workspace/ClasesPython/clase-18

# %%
import numpy as np # as np le ha dado de "apodo" np a numpy

numeros = [10,2,5,98,3]

array_numero = np.array(numeros)

print(np.mean(array_numero)) #mean lo que hace es sacar la media de un array (array si es con numpy, lista si es python)
# Out:
# 23.6
